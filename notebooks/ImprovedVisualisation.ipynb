# %% [markdown]
# # Notes
# I am not too sure who did this but I felt that it is quite unncessary. Apart from being inconclusive, it is unrelated to GDP and education. I would probably delete this notebook.

# %%
#Required imports for the project
import requests # for api requests
import pandas as pd #tabular data

# %%
api_key = ""

# %%
#creating a dataframe function
def json_to_dataframe(response):
    return pd.DataFrame(response.json()[1:], columns=response.json()[0])
#

# %%
#Setting up the API Query parameters for the 
params1 = {"NAICS2017" : 61}

# %%
#Requesting the json file from the census website using the api key
url = "https://api.census.gov/data/2017/ecnbasic?get=NAICS2017_LABEL,NAICS2017,GEO_ID,FIRM&for=county:*&key={}".format(api_key)
response = requests.request("GET", url, params=params1)

# %%
response.text[0:77]
# Out:
# '[["NAICS2017_LABEL","NAICS2017","GEO_ID","FIRM","NAICS2017","state","county"]'

# %%
#Converting ecn data frame into pandas data frame
educational_services = json_to_dataframe(response)
df = pd.DataFrame(data = educational_services)
df['FIRM'] = df['FIRM'].astype(int)
df['state'] = df['state'].astype("string")
df_california1 = df[df['state'] == '06']

# %%
# Top 5 counties with largest number of educational services
df_c_sort = df_california1\
.sort_values(by=['FIRM'], ascending=False)\
.head(10)
print('Top 10 counties with the most amount of educational services in California')
df_c_sort
# Out:
# Top 10 counties with the most amount of educational services in California
#           NAICS2017_LABEL NAICS2017          GEO_ID  FIRM NAICS2017 state  \
# 298  Educational services        61  0500000US06037  2787        61    06
# 314  Educational services        61  0500000US06059  1187        61    06
# 329  Educational services        61  0500000US06073  1010        61    06
# 301  Educational services        61  0500000US06085   822        61    06
# 209  Educational services        61  0500000US06001   693        61    06
# 214  Educational services        61  0500000US06075   470        61    06
# 210  Educational services        61  0500000US06067   334        61    06
# 318  Educational services        61  0500000US06081   323        61    06
# 299  Educational services        61  0500000US06065   313        61    06
# 203  Educational services        61  0500000US06013   295        61    06
#
#     county
# 298    037
# 314    059
# 329    073
# 301    085
# 209    001
# 214    075
# 210    067
# 318    081
# 299    065
# 203    013

# %%
#Setting the params
params2 = {"state" : "06"}

# %%
df
# Out:
#            NAICS2017_LABEL NAICS2017          GEO_ID  FIRM NAICS2017 state  \
# 0     Educational services        61  0500000US47177     5        61    47
# 1     Educational services        61  0500000US47179     0        61    47
# 2     Educational services        61  0500000US47183     0        61    47
# 3     Educational services        61  0500000US47005     0        61    47
# 4     Educational services        61  0500000US47119     0        61    47
# ...                    ...       ...             ...   ...       ...   ...
# 1454  Educational services        61  0500000US27059     4        61    27
# 1455  Educational services        61  0500000US27099     6        61    27
# 1456  Educational services        61  0500000US27105     3        61    27
# 1457  Educational services        61  0500000US27115     5        61    27
# 1458  Educational services        61  0500000US27109    37        61    27
#
#      county
# 0       177
# 1       179
# 2       183
# 3       005
# 4       119
# ...     ...
# 1454    059
# 1455    099
# 1456    105
# 1457    115
# 1458    109
#
# [1459 rows x 7 columns]

# %%
#Getting the ACS data
#Requesting the json file from the census website using the api key 
url = "https://api.census.gov/data/2017/acs/acs1/profile?get=DP02_0064PE,DP02_0088PE,DP02_0123PE&for=county&key={}".format(api_key)
response2 = requests.request("GET", url)

# %%
#Seeing what the columns for the data are
response2.text[0:61]
#Meaning of variables
#DP02_0064PE = Percent!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree
#DP02_0088PE = Percent!!PLACE OF BIRTH!!Total population!!Native!!Born in United States 
#DP02_0123PE = Percent!!ANCESTRY!!Total population!!American
# Out:
# '[["DP02_0064PE","DP02_0088PE","DP02_0123PE","state","county"]'

# %%
pop_chars = json_to_dataframe(response2)
df = pd.DataFrame(data = pop_chars)
df_california2 = df[df['state'] == '06']

# %%
#Merging the two datasets
merged_census = pd.merge(df_california1, df_california2, on='county')
merged_census.head()
# Out:
#         NAICS2017_LABEL NAICS2017          GEO_ID  FIRM NAICS2017 state_x  \
# 0  Educational services        61  0500000US06047    13        61      06
# 1  Educational services        61  0500000US06033     8        61      06
# 2  Educational services        61  0500000US06115     0        61      06
# 3  Educational services        61  0500000US06013   295        61      06
# 4  Educational services        61  0500000US06099    71        61      06
#
#   county DP02_0064PE DP02_0088PE DP02_0123PE state_y
# 0    047         8.7        74.4         1.7      06
# 1    033         9.5        91.8         2.3      06
# 2    115        13.9        85.4         2.1      06
# 3    013        26.7        72.9         2.7      06
# 4    099        12.0        77.3         3.0      06

# %%
merged_census
# Out:
#          NAICS2017_LABEL NAICS2017          GEO_ID  FIRM NAICS2017 state_x  \
# 0   Educational services        61  0500000US06047    13        61      06
# 1   Educational services        61  0500000US06033     8        61      06
# 2   Educational services        61  0500000US06115     0        61      06
# 3   Educational services        61  0500000US06013   295        61      06
# 4   Educational services        61  0500000US06099    71        61      06
# 5   Educational services        61  0500000US06083   137        61      06
# 6   Educational services        61  0500000US06097   161        61      06
# 7   Educational services        61  0500000US06025     5        61      06
# 8   Educational services        61  0500000US06001   693        61      06
# 9   Educational services        61  0500000US06067   334        61      06
# 10  Educational services        61  0500000US06017    37        61      06
# 11  Educational services        61  0500000US06055    44        61      06
# 12  Educational services        61  0500000US06053    73        61      06
# 13  Educational services        61  0500000US06075   470        61      06
# 14  Educational services        61  0500000US06107    34        61      06
# 15  Educational services        61  0500000US06113    37        61      06
# 16  Educational services        61  0500000US06023    23        61      06
# 17  Educational services        61  0500000US06057    34        61      06
# 18  Educational services        61  0500000US06039    14        61      06
# 19  Educational services        61  0500000US06045    19        61      06
# 20  Educational services        61  0500000US06087   137        61      06
# 21  Educational services        61  0500000US06037  2787        61      06
# 22  Educational services        61  0500000US06065   313        61      06
# 23  Educational services        61  0500000US06071   283        61      06
# 24  Educational services        61  0500000US06085   822        61      06
# 25  Educational services        61  0500000US06041   160        61      06
# 26  Educational services        61  0500000US06061   123        61      06
# 27  Educational services        61  0500000US06089    29        61      06
# 28  Educational services        61  0500000US06095    62        61      06
# 29  Educational services        61  0500000US06007    40        61      06
# 30  Educational services        61  0500000US06031     0        61      06
# 31  Educational services        61  0500000US06079    69        61      06
# 32  Educational services        61  0500000US06019   122        61      06
# 33  Educational services        61  0500000US06029    75        61      06
# 34  Educational services        61  0500000US06059  1187        61      06
# 35  Educational services        61  0500000US06111   217        61      06
# 36  Educational services        61  0500000US06101     0        61      06
# 37  Educational services        61  0500000US06081   323        61      06
# 38  Educational services        61  0500000US06077    82        61      06
# 39  Educational services        61  0500000US06073  1010        61      06
#
#    county DP02_0064PE DP02_0088PE   DP02_0123PE state_y
# 0     047         8.7        74.4           1.7      06
# 1     033         9.5        91.8           2.3      06
# 2     115        13.9        85.4           2.1      06
# 3     013        26.7        72.9           2.7      06
# 4     099        12.0        77.3           3.0      06
# 5     083        21.2        76.2           1.8      06
# 6     097        22.6        82.0           2.7      06
# 7     025        10.4        66.1  -999999999.0      06
# 8     001        26.9        65.1           2.1      06
# 9     067        20.0        77.2           2.5      06
# 10    017        22.7        89.3           3.7      06
# 11    055        23.4        77.1           3.2      06
# 12    053        14.9        67.9           1.3      06
# 13    075        35.1        62.2           3.1      06
# 14    107        10.1        77.3           1.2      06
# 15    113        20.1        74.5           1.6      06
# 16    023        21.5        93.0           3.6      06
# 17    057        22.6        94.1           3.1      06
# 18    039        10.6        78.2           1.2      06
# 19    045        16.2        85.2           2.3      06
# 20    087        23.8        78.9           2.5      06
# 21    037        21.1        64.5           3.4      06
# 22    065        14.3        77.5           3.1      06
# 23    071        13.6        78.8           1.8      06
# 24    085        26.9        59.0           1.7      06
# 25    041        32.8        79.1           1.8      06
# 26    061        24.4        86.6           3.1      06
# 27    089        15.2        93.1           7.6      06
# 28    095        18.4        77.3           2.5      06
# 29    007        16.7        91.6           8.9      06
# 30    031         9.4        79.2           2.2      06
# 31    079        19.8        88.7           4.0      06
# 32    019        13.8        78.7           1.7      06
# 33    029        10.4        79.4           2.9      06
# 34    059        26.1        68.5           5.0      06
# 35    111        21.9        77.5           5.2      06
# 36    101        11.7        75.8           4.2      06
# 37    081        28.6        63.2           2.0      06
# 38    077        13.1        75.6           1.3      06
# 39    073        23.7        74.7           2.8      06

# %%
merged_census.shape
# Out:
# (40, 11)

# %%
merged_census.rename(columns={'DP02_0064PE': 'pct of over 25s with Bachelors'}, inplace=True)

# %%
merged_census
# Out:
#          NAICS2017_LABEL NAICS2017          GEO_ID  FIRM NAICS2017 state_x  \
# 0   Educational services        61  0500000US06047    13        61      06
# 1   Educational services        61  0500000US06033     8        61      06
# 2   Educational services        61  0500000US06115     0        61      06
# 3   Educational services        61  0500000US06013   295        61      06
# 4   Educational services        61  0500000US06099    71        61      06
# 5   Educational services        61  0500000US06083   137        61      06
# 6   Educational services        61  0500000US06097   161        61      06
# 7   Educational services        61  0500000US06025     5        61      06
# 8   Educational services        61  0500000US06001   693        61      06
# 9   Educational services        61  0500000US06067   334        61      06
# 10  Educational services        61  0500000US06017    37        61      06
# 11  Educational services        61  0500000US06055    44        61      06
# 12  Educational services        61  0500000US06053    73        61      06
# 13  Educational services        61  0500000US06075   470        61      06
# 14  Educational services        61  0500000US06107    34        61      06
# 15  Educational services        61  0500000US06113    37        61      06
# 16  Educational services        61  0500000US06023    23        61      06
# 17  Educational services        61  0500000US06057    34        61      06
# 18  Educational services        61  0500000US06039    14        61      06
# 19  Educational services        61  0500000US06045    19        61      06
# 20  Educational services        61  0500000US06087   137        61      06
# 21  Educational services        61  0500000US06037  2787        61      06
# 22  Educational services        61  0500000US06065   313        61      06
# 23  Educational services        61  0500000US06071   283        61      06
# 24  Educational services        61  0500000US06085   822        61      06
# 25  Educational services        61  0500000US06041   160        61      06
# 26  Educational services        61  0500000US06061   123        61      06
# 27  Educational services        61  0500000US06089    29        61      06
# 28  Educational services        61  0500000US06095    62        61      06
# 29  Educational services        61  0500000US06007    40        61      06
# 30  Educational services        61  0500000US06031     0        61      06
# 31  Educational services        61  0500000US06079    69        61      06
# 32  Educational services        61  0500000US06019   122        61      06
# 33  Educational services        61  0500000US06029    75        61      06
# 34  Educational services        61  0500000US06059  1187        61      06
# 35  Educational services        61  0500000US06111   217        61      06
# 36  Educational services        61  0500000US06101     0        61      06
# 37  Educational services        61  0500000US06081   323        61      06
# 38  Educational services        61  0500000US06077    82        61      06
# 39  Educational services        61  0500000US06073  1010        61      06
#
#    county pct of over 25s with Bachelors DP02_0088PE   DP02_0123PE state_y
# 0     047                            8.7        74.4           1.7      06
# 1     033                            9.5        91.8           2.3      06
# 2     115                           13.9        85.4           2.1      06
# 3     013                           26.7        72.9           2.7      06
# 4     099                           12.0        77.3           3.0      06
# 5     083                           21.2        76.2           1.8      06
# 6     097                           22.6        82.0           2.7      06
# 7     025                           10.4        66.1  -999999999.0      06
# 8     001                           26.9        65.1           2.1      06
# 9     067                           20.0        77.2           2.5      06
# 10    017                           22.7        89.3           3.7      06
# 11    055                           23.4        77.1           3.2      06
# 12    053                           14.9        67.9           1.3      06
# 13    075                           35.1        62.2           3.1      06
# 14    107                           10.1        77.3           1.2      06
# 15    113                           20.1        74.5           1.6      06
# 16    023                           21.5        93.0           3.6      06
# 17    057                           22.6        94.1           3.1      06
# 18    039                           10.6        78.2           1.2      06
# 19    045                           16.2        85.2           2.3      06
# 20    087                           23.8        78.9           2.5      06
# 21    037                           21.1        64.5           3.4      06
# 22    065                           14.3        77.5           3.1      06
# 23    071                           13.6        78.8           1.8      06
# 24    085                           26.9        59.0           1.7      06
# 25    041                           32.8        79.1           1.8      06
# 26    061                           24.4        86.6           3.1      06
# 27    089                           15.2        93.1           7.6      06
# 28    095                           18.4        77.3           2.5      06
# 29    007                           16.7        91.6           8.9      06
# 30    031                            9.4        79.2           2.2      06
# 31    079                           19.8        88.7           4.0      06
# 32    019                           13.8        78.7           1.7      06
# 33    029                           10.4        79.4           2.9      06
# 34    059                           26.1        68.5           5.0      06
# 35    111                           21.9        77.5           5.2      06
# 36    101                           11.7        75.8           4.2      06
# 37    081                           28.6        63.2           2.0      06
# 38    077                           13.1        75.6           1.3      06
# 39    073                           23.7        74.7           2.8      06

# %%
merged_census.rename(columns={'DP02_0088PE': 'pct born in US'}, inplace=True)

# %%
merged_census
# Out:
#          NAICS2017_LABEL NAICS2017          GEO_ID  FIRM NAICS2017 state_x  \
# 0   Educational services        61  0500000US06047    13        61      06
# 1   Educational services        61  0500000US06033     8        61      06
# 2   Educational services        61  0500000US06115     0        61      06
# 3   Educational services        61  0500000US06013   295        61      06
# 4   Educational services        61  0500000US06099    71        61      06
# 5   Educational services        61  0500000US06083   137        61      06
# 6   Educational services        61  0500000US06097   161        61      06
# 7   Educational services        61  0500000US06025     5        61      06
# 8   Educational services        61  0500000US06001   693        61      06
# 9   Educational services        61  0500000US06067   334        61      06
# 10  Educational services        61  0500000US06017    37        61      06
# 11  Educational services        61  0500000US06055    44        61      06
# 12  Educational services        61  0500000US06053    73        61      06
# 13  Educational services        61  0500000US06075   470        61      06
# 14  Educational services        61  0500000US06107    34        61      06
# 15  Educational services        61  0500000US06113    37        61      06
# 16  Educational services        61  0500000US06023    23        61      06
# 17  Educational services        61  0500000US06057    34        61      06
# 18  Educational services        61  0500000US06039    14        61      06
# 19  Educational services        61  0500000US06045    19        61      06
# 20  Educational services        61  0500000US06087   137        61      06
# 21  Educational services        61  0500000US06037  2787        61      06
# 22  Educational services        61  0500000US06065   313        61      06
# 23  Educational services        61  0500000US06071   283        61      06
# 24  Educational services        61  0500000US06085   822        61      06
# 25  Educational services        61  0500000US06041   160        61      06
# 26  Educational services        61  0500000US06061   123        61      06
# 27  Educational services        61  0500000US06089    29        61      06
# 28  Educational services        61  0500000US06095    62        61      06
# 29  Educational services        61  0500000US06007    40        61      06
# 30  Educational services        61  0500000US06031     0        61      06
# 31  Educational services        61  0500000US06079    69        61      06
# 32  Educational services        61  0500000US06019   122        61      06
# 33  Educational services        61  0500000US06029    75        61      06
# 34  Educational services        61  0500000US06059  1187        61      06
# 35  Educational services        61  0500000US06111   217        61      06
# 36  Educational services        61  0500000US06101     0        61      06
# 37  Educational services        61  0500000US06081   323        61      06
# 38  Educational services        61  0500000US06077    82        61      06
# 39  Educational services        61  0500000US06073  1010        61      06
#
#    county pct of over 25s with Bachelors pct born in US   DP02_0123PE state_y
# 0     047                            8.7           74.4           1.7      06
# 1     033                            9.5           91.8           2.3      06
# 2     115                           13.9           85.4           2.1      06
# 3     013                           26.7           72.9           2.7      06
# 4     099                           12.0           77.3           3.0      06
# 5     083                           21.2           76.2           1.8      06
# 6     097                           22.6           82.0           2.7      06
# 7     025                           10.4           66.1  -999999999.0      06
# 8     001                           26.9           65.1           2.1      06
# 9     067                           20.0           77.2           2.5      06
# 10    017                           22.7           89.3           3.7      06
# 11    055                           23.4           77.1           3.2      06
# 12    053                           14.9           67.9           1.3      06
# 13    075                           35.1           62.2           3.1      06
# 14    107                           10.1           77.3           1.2      06
# 15    113                           20.1           74.5           1.6      06
# 16    023                           21.5           93.0           3.6      06
# 17    057                           22.6           94.1           3.1      06
# 18    039                           10.6           78.2           1.2      06
# 19    045                           16.2           85.2           2.3      06
# 20    087                           23.8           78.9           2.5      06
# 21    037                           21.1           64.5           3.4      06
# 22    065                           14.3           77.5           3.1      06
# 23    071                           13.6           78.8           1.8      06
# 24    085                           26.9           59.0           1.7      06
# 25    041                           32.8           79.1           1.8      06
# 26    061                           24.4           86.6           3.1      06
# 27    089                           15.2           93.1           7.6      06
# 28    095                           18.4           77.3           2.5      06
# 29    007                           16.7           91.6           8.9      06
# 30    031                            9.4           79.2           2.2      06
# 31    079                           19.8           88.7           4.0      06
# 32    019                           13.8           78.7           1.7      06
# 33    029                           10.4           79.4           2.9      06
# 34    059                           26.1           68.5           5.0      06
# 35    111                           21.9           77.5           5.2      06
# 36    101                           11.7           75.8           4.2      06
# 37    081                           28.6           63.2           2.0      06
# 38    077                           13.1           75.6           1.3      06
# 39    073                           23.7           74.7           2.8      06

# %%
merged_census
# Out:
#          NAICS2017_LABEL NAICS2017          GEO_ID  FIRM NAICS2017 state_x  \
# 0   Educational services        61  0500000US06047    13        61      06
# 1   Educational services        61  0500000US06033     8        61      06
# 2   Educational services        61  0500000US06115     0        61      06
# 3   Educational services        61  0500000US06013   295        61      06
# 4   Educational services        61  0500000US06099    71        61      06
# 5   Educational services        61  0500000US06083   137        61      06
# 6   Educational services        61  0500000US06097   161        61      06
# 7   Educational services        61  0500000US06025     5        61      06
# 8   Educational services        61  0500000US06001   693        61      06
# 9   Educational services        61  0500000US06067   334        61      06
# 10  Educational services        61  0500000US06017    37        61      06
# 11  Educational services        61  0500000US06055    44        61      06
# 12  Educational services        61  0500000US06053    73        61      06
# 13  Educational services        61  0500000US06075   470        61      06
# 14  Educational services        61  0500000US06107    34        61      06
# 15  Educational services        61  0500000US06113    37        61      06
# 16  Educational services        61  0500000US06023    23        61      06
# 17  Educational services        61  0500000US06057    34        61      06
# 18  Educational services        61  0500000US06039    14        61      06
# 19  Educational services        61  0500000US06045    19        61      06
# 20  Educational services        61  0500000US06087   137        61      06
# 21  Educational services        61  0500000US06037  2787        61      06
# 22  Educational services        61  0500000US06065   313        61      06
# 23  Educational services        61  0500000US06071   283        61      06
# 24  Educational services        61  0500000US06085   822        61      06
# 25  Educational services        61  0500000US06041   160        61      06
# 26  Educational services        61  0500000US06061   123        61      06
# 27  Educational services        61  0500000US06089    29        61      06
# 28  Educational services        61  0500000US06095    62        61      06
# 29  Educational services        61  0500000US06007    40        61      06
# 30  Educational services        61  0500000US06031     0        61      06
# 31  Educational services        61  0500000US06079    69        61      06
# 32  Educational services        61  0500000US06019   122        61      06
# 33  Educational services        61  0500000US06029    75        61      06
# 34  Educational services        61  0500000US06059  1187        61      06
# 35  Educational services        61  0500000US06111   217        61      06
# 36  Educational services        61  0500000US06101     0        61      06
# 37  Educational services        61  0500000US06081   323        61      06
# 38  Educational services        61  0500000US06077    82        61      06
# 39  Educational services        61  0500000US06073  1010        61      06
#
#    county pct of over 25s with Bachelors pct born in US   DP02_0123PE state_y
# 0     047                            8.7           74.4           1.7      06
# 1     033                            9.5           91.8           2.3      06
# 2     115                           13.9           85.4           2.1      06
# 3     013                           26.7           72.9           2.7      06
# 4     099                           12.0           77.3           3.0      06
# 5     083                           21.2           76.2           1.8      06
# 6     097                           22.6           82.0           2.7      06
# 7     025                           10.4           66.1  -999999999.0      06
# 8     001                           26.9           65.1           2.1      06
# 9     067                           20.0           77.2           2.5      06
# 10    017                           22.7           89.3           3.7      06
# 11    055                           23.4           77.1           3.2      06
# 12    053                           14.9           67.9           1.3      06
# 13    075                           35.1           62.2           3.1      06
# 14    107                           10.1           77.3           1.2      06
# 15    113                           20.1           74.5           1.6      06
# 16    023                           21.5           93.0           3.6      06
# 17    057                           22.6           94.1           3.1      06
# 18    039                           10.6           78.2           1.2      06
# 19    045                           16.2           85.2           2.3      06
# 20    087                           23.8           78.9           2.5      06
# 21    037                           21.1           64.5           3.4      06
# 22    065                           14.3           77.5           3.1      06
# 23    071                           13.6           78.8           1.8      06
# 24    085                           26.9           59.0           1.7      06
# 25    041                           32.8           79.1           1.8      06
# 26    061                           24.4           86.6           3.1      06
# 27    089                           15.2           93.1           7.6      06
# 28    095                           18.4           77.3           2.5      06
# 29    007                           16.7           91.6           8.9      06
# 30    031                            9.4           79.2           2.2      06
# 31    079                           19.8           88.7           4.0      06
# 32    019                           13.8           78.7           1.7      06
# 33    029                           10.4           79.4           2.9      06
# 34    059                           26.1           68.5           5.0      06
# 35    111                           21.9           77.5           5.2      06
# 36    101                           11.7           75.8           4.2      06
# 37    081                           28.6           63.2           2.0      06
# 38    077                           13.1           75.6           1.3      06
# 39    073                           23.7           74.7           2.8      06

# %%
merged_census
# Out:
#          NAICS2017_LABEL NAICS2017          GEO_ID  FIRM NAICS2017 state_x  \
# 0   Educational services        61  0500000US06047    13        61      06
# 1   Educational services        61  0500000US06033     8        61      06
# 2   Educational services        61  0500000US06115     0        61      06
# 3   Educational services        61  0500000US06013   295        61      06
# 4   Educational services        61  0500000US06099    71        61      06
# 5   Educational services        61  0500000US06083   137        61      06
# 6   Educational services        61  0500000US06097   161        61      06
# 7   Educational services        61  0500000US06025     5        61      06
# 8   Educational services        61  0500000US06001   693        61      06
# 9   Educational services        61  0500000US06067   334        61      06
# 10  Educational services        61  0500000US06017    37        61      06
# 11  Educational services        61  0500000US06055    44        61      06
# 12  Educational services        61  0500000US06053    73        61      06
# 13  Educational services        61  0500000US06075   470        61      06
# 14  Educational services        61  0500000US06107    34        61      06
# 15  Educational services        61  0500000US06113    37        61      06
# 16  Educational services        61  0500000US06023    23        61      06
# 17  Educational services        61  0500000US06057    34        61      06
# 18  Educational services        61  0500000US06039    14        61      06
# 19  Educational services        61  0500000US06045    19        61      06
# 20  Educational services        61  0500000US06087   137        61      06
# 21  Educational services        61  0500000US06037  2787        61      06
# 22  Educational services        61  0500000US06065   313        61      06
# 23  Educational services        61  0500000US06071   283        61      06
# 24  Educational services        61  0500000US06085   822        61      06
# 25  Educational services        61  0500000US06041   160        61      06
# 26  Educational services        61  0500000US06061   123        61      06
# 27  Educational services        61  0500000US06089    29        61      06
# 28  Educational services        61  0500000US06095    62        61      06
# 29  Educational services        61  0500000US06007    40        61      06
# 30  Educational services        61  0500000US06031     0        61      06
# 31  Educational services        61  0500000US06079    69        61      06
# 32  Educational services        61  0500000US06019   122        61      06
# 33  Educational services        61  0500000US06029    75        61      06
# 34  Educational services        61  0500000US06059  1187        61      06
# 35  Educational services        61  0500000US06111   217        61      06
# 36  Educational services        61  0500000US06101     0        61      06
# 37  Educational services        61  0500000US06081   323        61      06
# 38  Educational services        61  0500000US06077    82        61      06
# 39  Educational services        61  0500000US06073  1010        61      06
#
#    county pct of over 25s with Bachelors pct born in US   DP02_0123PE state_y
# 0     047                            8.7           74.4           1.7      06
# 1     033                            9.5           91.8           2.3      06
# 2     115                           13.9           85.4           2.1      06
# 3     013                           26.7           72.9           2.7      06
# 4     099                           12.0           77.3           3.0      06
# 5     083                           21.2           76.2           1.8      06
# 6     097                           22.6           82.0           2.7      06
# 7     025                           10.4           66.1  -999999999.0      06
# 8     001                           26.9           65.1           2.1      06
# 9     067                           20.0           77.2           2.5      06
# 10    017                           22.7           89.3           3.7      06
# 11    055                           23.4           77.1           3.2      06
# 12    053                           14.9           67.9           1.3      06
# 13    075                           35.1           62.2           3.1      06
# 14    107                           10.1           77.3           1.2      06
# 15    113                           20.1           74.5           1.6      06
# 16    023                           21.5           93.0           3.6      06
# 17    057                           22.6           94.1           3.1      06
# 18    039                           10.6           78.2           1.2      06
# 19    045                           16.2           85.2           2.3      06
# 20    087                           23.8           78.9           2.5      06
# 21    037                           21.1           64.5           3.4      06
# 22    065                           14.3           77.5           3.1      06
# 23    071                           13.6           78.8           1.8      06
# 24    085                           26.9           59.0           1.7      06
# 25    041                           32.8           79.1           1.8      06
# 26    061                           24.4           86.6           3.1      06
# 27    089                           15.2           93.1           7.6      06
# 28    095                           18.4           77.3           2.5      06
# 29    007                           16.7           91.6           8.9      06
# 30    031                            9.4           79.2           2.2      06
# 31    079                           19.8           88.7           4.0      06
# 32    019                           13.8           78.7           1.7      06
# 33    029                           10.4           79.4           2.9      06
# 34    059                           26.1           68.5           5.0      06
# 35    111                           21.9           77.5           5.2      06
# 36    101                           11.7           75.8           4.2      06
# 37    081                           28.6           63.2           2.0      06
# 38    077                           13.1           75.6           1.3      06
# 39    073                           23.7           74.7           2.8      06

# %%
merged_census2 = merged_census[['GEO_ID', 'FIRM', 'county','pct of over 25s with Bachelors', 'pct born in US']]

# %%
merged_census2
# Out:
#             GEO_ID  FIRM county pct of over 25s with Bachelors pct born in US
# 0   0500000US06047    13    047                            8.7           74.4
# 1   0500000US06033     8    033                            9.5           91.8
# 2   0500000US06115     0    115                           13.9           85.4
# 3   0500000US06013   295    013                           26.7           72.9
# 4   0500000US06099    71    099                           12.0           77.3
# 5   0500000US06083   137    083                           21.2           76.2
# 6   0500000US06097   161    097                           22.6           82.0
# 7   0500000US06025     5    025                           10.4           66.1
# 8   0500000US06001   693    001                           26.9           65.1
# 9   0500000US06067   334    067                           20.0           77.2
# 10  0500000US06017    37    017                           22.7           89.3
# 11  0500000US06055    44    055                           23.4           77.1
# 12  0500000US06053    73    053                           14.9           67.9
# 13  0500000US06075   470    075                           35.1           62.2
# 14  0500000US06107    34    107                           10.1           77.3
# 15  0500000US06113    37    113                           20.1           74.5
# 16  0500000US06023    23    023                           21.5           93.0
# 17  0500000US06057    34    057                           22.6           94.1
# 18  0500000US06039    14    039                           10.6           78.2
# 19  0500000US06045    19    045                           16.2           85.2
# 20  0500000US06087   137    087                           23.8           78.9
# 21  0500000US06037  2787    037                           21.1           64.5
# 22  0500000US06065   313    065                           14.3           77.5
# 23  0500000US06071   283    071                           13.6           78.8
# 24  0500000US06085   822    085                           26.9           59.0
# 25  0500000US06041   160    041                           32.8           79.1
# 26  0500000US06061   123    061                           24.4           86.6
# 27  0500000US06089    29    089                           15.2           93.1
# 28  0500000US06095    62    095                           18.4           77.3
# 29  0500000US06007    40    007                           16.7           91.6
# 30  0500000US06031     0    031                            9.4           79.2
# 31  0500000US06079    69    079                           19.8           88.7
# 32  0500000US06019   122    019                           13.8           78.7
# 33  0500000US06029    75    029                           10.4           79.4
# 34  0500000US06059  1187    059                           26.1           68.5
# 35  0500000US06111   217    111                           21.9           77.5
# 36  0500000US06101     0    101                           11.7           75.8
# 37  0500000US06081   323    081                           28.6           63.2
# 38  0500000US06077    82    077                           13.1           75.6
# 39  0500000US06073  1010    073                           23.7           74.7

# %%
from plotnine import *


# Create scatterplot with % over 25 w/ Bachelors on x-axis and % population who are native on y-axis
ggplot(merged_census2, aes(x ='pct of over 25s with Bachelors', y ='pct born in US')) + \
    geom_point()
# Out:
# <ggplot: (8775872424780)>

# %%
merged_census2.dtypes
# Out:
# GEO_ID                            object
# FIRM                               int64
# county                            object
# pct of over 25s with Bachelors    object
# pct born in US                    object
# dtype: object

# %%
import pandas as pd
from plotnine import *


# convert 'x' to a numeric data type
merged_census2['pct of over 25s with Bachelors'] = merged_census2['pct of over 25s with Bachelors'].astype(float)
merged_census2['pct born in US'] = merged_census2['pct born in US'].astype(float)


# create scatterplot with continuous scale
plot3 = (ggplot(merged_census2, aes(x='pct of over 25s with Bachelors', y='pct born in US')) +
 geom_point())
         
plot3
# Out:
# /var/folders/19/pptcsj1d2d97pbcfphs_4bl00000gn/T/ipykernel_12612/2831162685.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/19/pptcsj1d2d97pbcfphs_4bl00000gn/T/ipykernel_12612/2831162685.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <ggplot: (8775894765960)>

# %%
import pandas as pd
from plotnine import *

# convert 'x' to a numeric data type
merged_census2['pct of over 25s with Bachelors'] = merged_census2['pct of over 25s with Bachelors'].astype(float)
merged_census2['pct born in US'] = merged_census2['pct born in US'].astype(float)

# create scatterplot with continuous scale and varying dot sizes based on 'FIRM'
plot3 = (ggplot(merged_census2, aes(x='pct of over 25s with Bachelors', y='pct born in US', size='FIRM')) +
         geom_point() +
         scale_size_continuous(range=(2, 10)))

plot3
# Out:
# /var/folders/19/pptcsj1d2d97pbcfphs_4bl00000gn/T/ipykernel_12612/4210862634.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/19/pptcsj1d2d97pbcfphs_4bl00000gn/T/ipykernel_12612/4210862634.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <ggplot: (8775861007767)>

# %%
import pandas as pd
from plotnine import *

# convert 'x' to a numeric data type
merged_census2['pct of over 25s with Bachelors'] = merged_census2['pct of over 25s with Bachelors'].astype(float)
merged_census2['pct born in US'] = merged_census2['pct born in US'].astype(float)

# create scatterplot with continuous scale and varying dot sizes based on 'FIRM'
plot3 = (ggplot(merged_census2, aes(x = 'pct of over 25s with Bachelors', y = 'pct born in US', size = 'FIRM')) +
         geom_point(color = 'blue') +
         scale_size_continuous(range = (2, 9)) +
         scale_color_manual(values = ['blue']) +
         theme(axis_text = element_text(family = "Arial",color='black', ))) + scale_color_gradient(limits=(0, 1))

plot3 = plot3 + labs(x="% of over 25s with Bachelor's degree", y='% Born in the United States') + theme(axis_text_x=element_text(family="Arial"))
plot3 = plot3 +  geom_point(aes(color='FIRM')) + \
    scale_color_gradient(low='grey', high='purple') 
plot3 + theme_minimal() + labs(color='No. of \nEducational Institutions per county') + theme(axis_text=element_text(style='italic', family = "Arial")) + \
        ggtitle("Does being born in the US have an influence on and\n higher education attainment in California?") +\
theme(plot_title=element_text(family="Arial")) +  theme(legend_position="right")
# Out:
# /var/folders/19/pptcsj1d2d97pbcfphs_4bl00000gn/T/ipykernel_12612/4074945516.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/19/pptcsj1d2d97pbcfphs_4bl00000gn/T/ipykernel_12612/4074945516.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/albertomartino/opt/anaconda3/lib/python3.9/site-packages/plotnine/scales/scales.py:36: PlotnineWarning: Scale for 'color' is already present.
# Adding another scale for 'color',
# which will replace the existing scale.
# <ggplot: (8775861084154)>
